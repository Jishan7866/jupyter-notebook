# %%
print('hello')
# Out:
# hello

# %%
# %pip list
# Out:
# Package                                Version
# -------------------------------------- ---------------
# absl-py                                1.4.0
# aiohttp                                3.8.4
# aiohttp-cors                           0.7.0
# aiorwlock                              1.3.0
# aiosignal                              1.3.1
# ansiwrap                               0.8.4
# anyio                                  3.6.2
# argon2-cffi                            21.3.0
# argon2-cffi-bindings                   21.2.0
# asttokens                              2.2.1
# async-timeout                          4.0.2
# attrs                                  22.2.0
# Babel                                  2.12.1
# backcall                               0.2.0
# backoff                                2.2.1
# backports.functools-lru-cache          1.6.4
# beatrix-jupyterlab                     2023.421.185927
# beautifulsoup4                         4.12.2
# ...

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'
